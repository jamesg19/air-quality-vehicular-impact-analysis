# %%
import csv
import pandas as pd

# %%
# CONFIGURACIÓN
INPUT_TXT = "./Data/Vehiculos/PARQUE-VEHICULAR-2007-2025-FULL.txt"
OUTPUT_CSV = "./Data/Vehiculos/PARQUE-VEHICULAR-2007-2025-FULL.csv"
ENCODING_INPUT = "cp1252"
ENCODING_OUTPUT = "utf-8"

# %%
print("=" * 80)
print("PASO 1: Leyendo archivo txt...")
print("=" * 80)

rows = []
with open(INPUT_TXT, "r", encoding=ENCODING_INPUT, newline="") as infile:
    reader = csv.reader(infile, delimiter="|", quotechar='"', escapechar="\\")
    for row in reader:
        rows.append(row)

if not rows:
    raise ValueError("El archivo de entrada está vacío.")

print(f"Filas leídas: {len(rows):,}")
# Out:
# ================================================================================
# PASO 1: Leyendo archivo txt...
# ================================================================================
# Filas leídas: 4,146,699

# %%
header = rows[0]
expected_columns = len(header)

filas_validas = [header]
filas_invalidas = []

for line_number, row in enumerate(rows[1:], start=2):
    if len(row) != expected_columns:
        filas_invalidas.append((line_number, row))
    else:
        filas_validas.append(row)

print("Validas:", len(filas_validas))
print("Invalidas:", len(filas_invalidas))
# Out:
# Validas: 4146698
# Invalidas: 1

# %%
df = pd.DataFrame(filas_validas[1:], columns=filas_validas[0])
df.columns = df.columns.str.strip()
df["ANIO_ALZA"] = pd.to_numeric(df["ANIO_ALZA"], errors="coerce")
df.head()
# Out:
#    ANIO_ALZA MES NOMBRE_DEPARTAMENTO       NOMBRE_MUNICIPIO MODELO_VEHICULO  \
# 0       2007  05           GUATEMALA  SAN JUAN SACATEPEQUEZ            1992
# 1       2007  05         EL PROGRESO              EL JICARO            2007
# 2       2007  05             JUTIAPA                 MOYUTA            2007
# 3       2007  05      QUETZALTENANGO         QUETZALTENANGO            2007
# 4       2007  05       HUEHUETENANGO                 CUILCO            1999
#
#             LINEA_VEHICULO TIPO_VEHICULO USO_VEHICULO MARCA_VEHICULO CANTIDAD
# 0                TERCEL DX     AUTOMOVIL   PARTICULAR         TOYOTA        1
# 1  BT-50 DBL CAB 4X2 TURBO       PICK UP   PARTICULAR          MAZDA        1
# 2                  JH100-2          MOTO  MOTOCICLETA        JIALING        1
# 3    ALTO LHD 800 STANDARD     AUTOMOVIL   PARTICULAR         SUZUKI        1
# 4       TACOMA 4X4 SR5 X/C       PICK UP   PARTICULAR         TOYOTA        1

# %%
df_filtrado = df[
    (df["NOMBRE_DEPARTAMENTO"] == "GUATEMALA") &
    (df["NOMBRE_MUNICIPIO"] == "GUATEMALA") &
    (df["ANIO_ALZA"] < 2026)
]

df_filtrado.shape
# Out:
# (557454, 10)

# %%
tipo_vehiculo = sorted(df_filtrado["TIPO_VEHICULO"].dropna().unique())
tipo_vehiculo
# Out:
# ['AMBULANCIA',
#  'ARA A',
#  'AUTOBUS',
#  'AUTOBUS ESCOLARP',
#  'AUTOMOVIL',
#  'BARREDORA INDUST',
#  'BUS',
#  'BUS ESCOLAR',
#  'CABEZAL',
#  'CAMION',
#  'CAMION BOMBEROS',
#  'CAMION CHASIS',
#  'CAMION CISTERNA',
#  'CAMION FRIGORIFICO',
#  'CAMION FURGON',
#  'CAMION GRUA',
#  'CAMION MEZCLADOR',
#  'CAMION PERFORADOR',
#  'CAMION VOLTEO',
#  'CAMIONETA',
#  'CAMIONETA AGRICOLA',
#  'CAMIONETA ESCOLA',
#  'CAMIONETA SPORT',
#  'CAMIONETILLA',
#  'CARRETA-CARRETON',
#  'CARRETILLA-AUTOM',
#  'CARRO FUNEBRE',
#  'CARRO PARA GOLF',
#  'CASA RODANTE',
#  'CISTERNA',
#  'COCHE VIVIENDA',
#  'CUATRIMOTO',
#  'ESPARCIDORA',
#  'FURGON',
#  'GO-KART',
#  'GONDOLA',
#  'GRANELERA',
#  'GRUA',
#  'GRUA HIDRAULICA',
#  'JAULA CANERA',
#  'JEEP',
#  'LIMOSINA',
#  'LOW BOY',
#  'MEZCLADORA',
#  'MICROBUS',
#  'MICROBUS ESCOLAR',
#  'MINI TRACTOR',
#  'MINIBUS',
#  'MINITRACTOR',
#  'MONTA CARGA',
#  'MOTO',
#  'OMNIBUS',
#  'PALANGANA',
#  'PANEL',
#  'PERFORADORA',
#  'PICK UP',
#  'PLATAFORMA',
#  'PORTA CONTENEDOR',
#  'RASTRA',
#  'REMOLQUE',
#  'RETROEXCAVADORA',
#  'SCOOTER',
#  'SEMI REMOLQUE',
#  'TACUASINA',
#  'TANQUE',
#  'TOLBA',
#  'TRACTO CAMION',
#  'TRACTOR',
#  'TRACTOR AGRICOLA',
#  'TRACTOR CONSTRUC',
#  'TRANS DE CARGA',
#  'TRIMOTO',
#  'VEHICULO RUSTICO',
#  'VOLQUETA']

# %%
livianos = {
    'AUTOMOVIL','AMBULANCIA','JEEP','PICK UP','CARRO PARA GOLF',
    'CAMIONETA','CAMIONETA AGRICOLA','CAMIONETA SPORT','CAMIONETILLA',
    'PANEL','MICROBUS','MICROBUS ESCOLAR','MINIBUS','MOTO','SCOOTER',
    'TRIMOTO','CUATRIMOTO','LIMOSINA','CARRO FUNEBRE','VEHICULO RUSTICO'
}
pesado = {
    'AUTOBUS',
    'AUTOBUS ESCOLARP',
    'BARREDORA INDUST',
    'BUS',
    'BUS ESCOLAR',
    'CABEZAL',
    'CAMION',
    'CAMION BOMBEROS',
    'CAMION CHASIS',
    'CAMION CISTERNA',
    'CAMION FRIGORIFICO',
    'CAMION FURGON',
    'CAMION GRUA',
    'CAMION MEZCLADOR',
    'CAMION PERFORADOR',
    'CAMION VOLTEO',
    'CISTERNA',
    'ESPARCIDORA',
    'FURGON',
    'GONDOLA',
    'GRANELERA',
    'GRUA',
    'GRUA HIDRAULICA',
    'JAULA CANERA',
    'LOW BOY',
    'MEZCLADORA',
    'MINIBUS',
    'OMNIBUS',
    'PERFORADORA',
    'PLATAFORMA',
    'PORTA CONTENEDOR',
    'RASTRA',
    'REMOLQUE',
    'RETROEXCAVADORA',
    'SEMI REMOLQUE',
    'TACUASINA',
    'TANQUE',
    'TOLBA',
    'TRACTO CAMION',
    'TRACTOR',
    'TRACTOR AGRICOLA',
    'TRACTOR CONSTRUC',
    'TRANS DE CARGA',
    'VOLQUETA'
}

# %%
#df_livianos = df_filtrado[df_filtrado["TIPO_VEHICULO"].isin(pesado)]
df_livianos= df_filtrado.copy()
df_livianos.shape
# Out:
# (557454, 10)

# %%
# Ejemplo: Eliminamos las columnas 'COLUMNA_A' y 'COLUMNA_B'
df_livianos = df_livianos.drop(columns=['NOMBRE_DEPARTAMENTO', 'NOMBRE_MUNICIPIO'])

# %%
df_livianos['CANTIDAD'] = pd.to_numeric(df_livianos['CANTIDAD'], errors='coerce')
df_livianos.head(5)
# Out:
#     ANIO_ALZA MES MODELO_VEHICULO   LINEA_VEHICULO TIPO_VEHICULO USO_VEHICULO  \
# 7        2007  05            2003  SANTA FE V6 4X2     CAMIONETA   PARTICULAR
# 12       2007  05            2001            SWIFT     AUTOMOVIL   PARTICULAR
# 15       2007  05            1995        METRO LSI     AUTOMOVIL   PARTICULAR
# 17       2007  05            2003            JETTA     AUTOMOVIL   PARTICULAR
# 19       2007  05            2007                5     CAMIONETA   PARTICULAR
#
#    MARCA_VEHICULO  CANTIDAD
# 7         HYUNDAI         1
# 12         SUZUKI         1
# 15            GEO         1
# 17     VOLKSWAGEN         1
# 19          MAZDA         5

# %%
#Suma de vehiculos
total_cantidad = df_livianos['CANTIDAD'].sum()
print(total_cantidad)
df_livianos
# Out:
# 1533790
#          ANIO_ALZA MES MODELO_VEHICULO             LINEA_VEHICULO  \
# 7             2007  05            2003            SANTA FE V6 4X2
# 12            2007  05            2001                      SWIFT
# 15            2007  05            1995                  METRO LSI
# 17            2007  05            2003                      JETTA
# 19            2007  05            2007                          5
# ...            ...  ..             ...                        ...
# 4146673       2012  06            1988                4X4 X/C SR5
# 4146674       2012  06            2009                  AVEO 5 LT
# 4146681       2012  08            1983                    4X4 SR5
# 4146683       2013  04            2003          CR-V REALTIME 4WD
# 4146694       2013  02            2013  BT-50 4X4 DOBLE CAB AUTOM
#
#         TIPO_VEHICULO USO_VEHICULO MARCA_VEHICULO  CANTIDAD
# 7           CAMIONETA   PARTICULAR        HYUNDAI         1
# 12          AUTOMOVIL   PARTICULAR         SUZUKI         1
# 15          AUTOMOVIL   PARTICULAR            GEO         1
# 17          AUTOMOVIL   PARTICULAR     VOLKSWAGEN         1
# 19          CAMIONETA   PARTICULAR          MAZDA         5
# ...               ...          ...            ...       ...
# 4146673       PICK UP   PARTICULAR         TOYOTA         1
# 4146674  CAMIONETILLA   PARTICULAR      CHEVROLET         1
# 4146681       PICK UP   PARTICULAR         TOYOTA         1
# 4146683     CAMIONETA   PARTICULAR          HONDA         1
# 4146694       PICK UP   PARTICULAR          MAZDA         1
#
# [557454 rows x 8 columns]

# %%
df_livianos.to_csv(OUTPUT_CSV, index=False,header=True, encoding=ENCODING_OUTPUT)
print("Archivo guardado:", OUTPUT_CSV)
# Out:
# Archivo guardado: ./Data/Vehiculos/PARQUE-VEHICULAR-2007-2025-FULL.csv
